# %%
# %matplotlib inline
# %pylab inline
import pandas as pd
import pylab as pl
import matplotlib.pyplot as plt
import palettable as pal
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_table = pd.read_csv("../assembly_evaluation_data/merged_annotation_stats.csv")
data_table = data_table[['SampleName','n_seqs', 'total_annotation_names','total_annotated_contigs', 'unique_annotations','annotations_w_false_crbb', 'total_OrthoDB', 'unique_OrthoDB',
'false_crbb_OrthoDB', 'total_Pfam', 'unique_Pfam', 'false_crbb_Pfam','total_Rfam', 'unique_Rfam', 'false_crbb_Rfam']]

# %%
data_table.head()
# Out:
#    SampleName  n_seqs  total_annotation_names  total_annotated_contigs  \
# 0  MMETSP0004   33559                 54240.0                    26851
# 1  MMETSP0005   32824                 54436.0                    26252
# 2  MMETSP0006   47463                 66289.0                    36795
# 3  MMETSP0007   30922                 24666.0                    17308
# 4  MMETSP0009   54275                 55697.0                    36990
#
#    unique_annotations  annotations_w_false_crbb  total_OrthoDB  \
# 0             12707.0                    2246.0          15073
# 1             12246.0                    1748.0          14760
# 2             17810.0                    4691.0          19610
# 3              7773.0                    1368.0           8469
# 4             12576.0                       NaN          11802
#
#    unique_OrthoDB  false_crbb_OrthoDB  total_Pfam  unique_Pfam  \
# 0          8726.0              1582.0       39033       5284.0
# ...

# %%
sns.violinplot(data_table.n_seqs)

# %%
sns.violinplot(data_table.unique_annotations)

# %%
sns.violinplot(data_table.annotations_w_false_crbb)

# %%
df_OrthoDB = data_table[['total_OrthoDB', 'unique_OrthoDB','false_crbb_OrthoDB']]
df_Pfam = data_table[['total_Pfam', 'unique_Pfam', 'false_crbb_Pfam']]
df_Rfam = data_table[['total_Rfam', 'unique_Rfam', 'false_crbb_Rfam']]

# %%
df_false = data_table[['false_crbb_OrthoDB','false_crbb_Pfam','false_crbb_Rfam']]
df_unique = data_table[['unique_OrthoDB','unique_Pfam','unique_Rfam']]
df_total = data_table[['total_OrthoDB','total_Pfam','total_Rfam']]

# %%
sns.violinplot(df_total)
# Out:
# /Users/cohenl06/anaconda3/envs/dammit_py3/lib/python3.5/site-packages/seaborn/categorical.py:2342: UserWarning: The violinplot API has been changed. Attempting to adjust your arguments for the new API (which might not work). Please update your code. See the version 0.6 release notes for more info.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(df_unique)
# Out:
# /Users/cohenl06/anaconda3/envs/dammit_py3/lib/python3.5/site-packages/seaborn/categorical.py:2342: UserWarning: The violinplot API has been changed. Attempting to adjust your arguments for the new API (which might not work). Please update your code. See the version 0.6 release notes for more info.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(df_false)
# Out:
# /Users/cohenl06/anaconda3/envs/dammit_py3/lib/python3.5/site-packages/seaborn/categorical.py:2342: UserWarning: The violinplot API has been changed. Attempting to adjust your arguments for the new API (which might not work). Please update your code. See the version 0.6 release notes for more info.
#   warnings.warn(msg, UserWarning)
