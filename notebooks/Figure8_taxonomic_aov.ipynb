# %%
#install.packages("klaR",dependencies=TRUE)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
#install.packages("AlgDesign",dependencies=TRUE)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
#install.packages("agricolae","/Users/johnsolk/anaconda3/envs/r_env/lib/R/library")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
#install.packages("multcomp",dependencies=TRUE)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(multcomp)
library(agricolae)
library(repr)
library(RColorBrewer)
# Out:
# Loading required package: mvtnorm
# Warning message:
# “package ‘mvtnorm’ was built under R version 3.4.3”Loading required package: survival
# Loading required package: TH.data
# Warning message:
# “package ‘TH.data’ was built under R version 3.4.3”Loading required package: MASS
#
# Attaching package: ‘TH.data’
#
# The following object is masked from ‘package:MASS’:
#
#     geyser

# %%
setwd("~/Documents/UCDavis/dib/MMETSP")

# %%
special_flowers = c("MMETSP0693","MMETSP1019","MMETSP0923","MMETSP0008","MMETSP1002","MMETSP1325","MMETSP1018",
                    "MMETSP1346","MMETSP0088","MMETSP0092","MMETSP0717","MMETSP0223","MMETSP0115","MMETSP0196",
                    "MMETSP0197","MMETSP0398","MMETSP0399","MMETSP0922")
tax_raw <- read.csv("assembly_evaluation_data/MMETSP_all_evaluation_matrix.csv")
dim(tax_raw)
# Out:
# [1] 719 289

# %%
# remove MMETSP with multiple SRA, aka "special flowers"
tax_raw <- tax_raw[!tax_raw$SampleName %in% special_flowers,]
dim(tax_raw)
# restrict to Unique_kmers, Phylum, n_seqs, Input.Reads, mean_orf_percent.x
phylum_data <-tax_raw[,c(2,34,41,45,54,266,271,283)]
phylum <- phylum_data$Phylum
# Restrict data to top 7 most common Phyla
sub_phy<-c("Bacillariophyta","Dinophyta","Ochrophyta","Haptophyta","Ciliophora","Chlorophyta","Cryptophyta")
sub<-phylum_data[phylum_data$Phylum %in% sub_phy,]
#colors=rainbow(9)
#colors=c('#8c510a','#bf812d','#dfc27d','#f6e8c3','#f5f5f5','#c7eae5','#80cdc1','#35978f','#01665e')
colors = palette(brewer.pal(n=8,name="Dark2"))
# Out:
# [1] 660 289

# %% [markdown]
# ## Size of dataset

# %%
print(colors)
# Out:
# [1] "black"   "red"     "green3"  "blue"    "cyan"    "magenta" "yellow"
# [8] "gray"

# %%
head(sub)
dim(sub)
# Out:
#   SampleName Phylum          Input.Reads n_seqs mean_orf_percent
# 1 MMETSP0004 Ochrophyta      24803955    33559  81.26381
# 2 MMETSP0005 Ochrophyta      28100060    32824  80.15649
# 3 MMETSP0006 Haptophyta      21466210    47463  80.79508
# 4 MMETSP0007 Haptophyta      20174360    30922  71.01950
# 7 MMETSP0009 Bacillariophyta 15820915    54275  80.37076
# 8 MMETSP0010 Bacillariophyta 11591751    43375  67.98617
#   DIB.Complete_eukaryotic_BUSCO_perc DIB.Complete_protist_BUSCO_prop
# 1 69.30693                           0.7179487
# 2 67.32673                           0.6880342
# 3 55.77558                           0.6452991
# 4 30.36304                           0.3974359
# 7 46.53465                           0.4743590
# 8 73.59736                           0.7521368
#   dib_assembly_unique_kmers
# 1 19837761
# 2 20350054
# 3 25286098
# 4 12496793
# 7 30074483
# 8 24840436
# [1] 530   8

# %%
summary(sub$Phylum)
class(sub$Phylum)
# Out:
#          Alveolata        Apicomplexa         Ascomycota    Bacillariophyta
#                  0                  0                  0                173
#        Bicosoecida           Cercozoa Chlorarachniophyta        Chlorophyta
#                  0                  0                  0                 62
#         Ciliophora        Cryptophyta          Dinophyta         Euglenozoa
#                 25                 22                114                  0
#       Foraminifera        Forminafera        Glaucophyta         Haptophyta
#                  0                  0                  0                 61
#      Labyrinthista         Ochrophyta        Perkinsozoa    Pyrrophycophyta
#                  0                 73                  0                  0
#         Rhodophyta  Sarcomastigophora            Unknown
#                  0                  0                  0
# [1] "factor"

# %% [markdown]
# ### Make category for "Others"

# %%
phylum_data$sub_Phylum <- ifelse(phylum_data$Phylum %in% sub_phy, as.character(phylum_data$Phylum),"Others")
head(phylum_data)
dim(phylum_data)
phylum_data$sub_Phylum <- as.factor(phylum_data$sub_Phylum)
class(phylum_data$sub_Phylum)
# Out:
#   SampleName Phylum          Input.Reads n_seqs mean_orf_percent
# 1 MMETSP0004 Ochrophyta      24803955    33559  81.26381
# 2 MMETSP0005 Ochrophyta      28100060    32824  80.15649
# 3 MMETSP0006 Haptophyta      21466210    47463  80.79508
# 4 MMETSP0007 Haptophyta      20174360    30922  71.01950
# 7 MMETSP0009 Bacillariophyta 15820915    54275  80.37076
# 8 MMETSP0010 Bacillariophyta 11591751    43375  67.98617
#   DIB.Complete_eukaryotic_BUSCO_perc DIB.Complete_protist_BUSCO_prop
# 1 69.30693                           0.7179487
# 2 67.32673                           0.6880342
# 3 55.77558                           0.6452991
# 4 30.36304                           0.3974359
# 7 46.53465                           0.4743590
# 8 73.59736                           0.7521368
#   dib_assembly_unique_kmers sub_Phylum
# 1 19837761                  Ochrophyta
# 2 20350054                  Ochrophyta
# 3 25286098                  Haptophyta
# 4 12496793                  Haptophyta
# ...

# %%
summary(phylum_data$sub_Phylum)
colnames(phylum_data)
length(colnames(phylum_data))
# Out:
# Bacillariophyta     Chlorophyta      Ciliophora     Cryptophyta       Dinophyta
#             173              62              25              22             114
#      Haptophyta      Ochrophyta          Others
#              61              73             130
# [1] "SampleName"                         "Phylum"
# [3] "Input.Reads"                        "n_seqs"
# [5] "mean_orf_percent"                   "DIB.Complete_eukaryotic_BUSCO_perc"
# [7] "DIB.Complete_protist_BUSCO_prop"    "dib_assembly_unique_kmers"
# [9] "sub_Phylum"
# [1] 9

# %%
phylum_data <- phylum_data[,c(1,3:9)]
phylum_data$Phylum <- phylum_data$sub_Phylum

# %%
sub <- phylum_data

# %% [markdown]
# ## Mean %ORF

# %%
fit <- aov(mean_orf_percent ~ Phylum,data=sub)
a<-HSD.test(fit,"Phylum",group=TRUE)
tuk<-glht(fit,linfct=mcp(Phylum="Tukey"))
summary(tuk)
tuk.cld.a<-cld(tuk)
opar<-par(mai=c(1,1,1.5,1))
options(repr.plot.width=12, repr.plot.height=10)
pdf("paper/Figure8_tukey_taxa_mean_orf.pdf",width=13,height=8.5)
#bottom, left, top and right margins
par(mar=c(6,6,8,2))
plot(tuk.cld.a,col=colors,ylab="Mean %ORF",cex.lab=1.5,cex.axis=1)
dev.off()
png("paper/Figure8_tukey_taxa_mean_orf.png",width=13,height=8.5,units="in",res=1200)
par(mar=c(6,6,8,2))
plot(tuk.cld.a,col=colors,ylab="Mean %ORF",cex.lab=1.5,cex.axis=1)
dev.off()
par(mar=c(4,5,7,2),cex=1.5,cex.lab=1.5,cex.axis=1)
plot(tuk.cld.a,col=colors,ylab="Mean %ORF",cex.axis=1)
# Out:
# Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: aov(formula = mean_orf_percent ~ Phylum, data = sub)
#
# Linear Hypotheses:
#                                    Estimate Std. Error t value Pr(>|t|)
# Chlorophyta - Bacillariophyta == 0  -0.9613     1.1791  -0.815  0.99132
# Ciliophora - Bacillariophyta == 0  -20.7047     1.6943 -12.220  < 0.001 ***
# Cryptophyta - Bacillariophyta == 0   6.1667     1.7923   3.441  0.01284 *
# Dinophyta - Bacillariophyta == 0    10.8851     0.9604  11.334  < 0.001 ***
# ...

# %%
as.character(unique(phylum_data$Phylum))
# Out:
# [1] "Ochrophyta"      "Haptophyta"      "Bacillariophyta" "Others"
# [5] "Ciliophora"      "Dinophyta"       "Chlorophyta"     "Cryptophyta"

# %% [markdown]
# # Unique k-mers

# %%
fit2 <- aov(dib_assembly_unique_kmers ~ Phylum,data=sub)
b<-TukeyHSD(fit2,"Phylum",conf.level=0.95)
tuk<-glht(fit2,linfct=mcp(Phylum="Tukey"))
summary(tuk)
tuk.cld.b<-cld(tuk)
opar<-par(mai=c(1,1,1.5,1))
options(repr.plot.width=12, repr.plot.height=10)
pdf("paper/Figure8_tukey_taxa_unique_kmers.pdf",width=13,height=8.5)
par(mar=c(6,6,8,2))
plot(tuk.cld.b,col=colors, ylab="Unique k-mers",cex.lab=1.5,cex.axis=1)
dev.off()
png("paper/Figure8_tukey_taxa_unique_kmers.png",width=13,height=8.5,units="in",res=1200)
par(mar=c(6,6,8,2))
plot(tuk.cld.b,col=colors, ylab="Unique k-mers",cex.lab=1.5,cex.axis=1)
dev.off()
par(mar=c(6,6,8,2))
plot(tuk.cld.b,col=colors, ylab="Unique k-mers",cex.lab=1.5,cex.axis=1)
# Out:
# Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: aov(formula = dib_assembly_unique_kmers ~ Phylum, data = sub)
#
# Linear Hypotheses:
#                                     Estimate Std. Error t value Pr(>|t|)
# Chlorophyta - Bacillariophyta == 0  -5846568    2414049  -2.422   0.2161
# Ciliophora - Bacillariophyta == 0    5771166    3489560   1.654   0.6987
# Cryptophyta - Bacillariophyta == 0   9239934    3691595   2.503   0.1818
# Dinophyta - Bacillariophyta == 0    32874643    1967418  16.710   <0.001 ***
# Haptophyta - Bacillariophyta == 0     932989    2428572   0.384   0.9999
# ...

# %% [markdown]
# # Number of Input reads

# %%
fit3 <- aov(Input.Reads ~ Phylum,data=sub)
b<-TukeyHSD(fit3,"Phylum",conf.level=0.95)
tuk<-glht(fit3,linfct=mcp(Phylum="Tukey"))
summary(tuk)
tuk.cld.c<-cld(tuk)
opar<-par(mai=c(1,1,1.5,1))
options(repr.plot.width=12, repr.plot.height=10)
pdf("paper/Figure8_tukey_taxa_input_Reads.pdf",width=13,height=8.5)
par(mar=c(6,6,8,2))
plot(tuk.cld.c,col=colors, ylab="Number of Input Reads",cex.lab=1.5,cex.axis=1)
png("paper/Figure8_tukey_taxa_input_Reads.png",width=13,height=8.5,units="in",res=1200)
dev.off()
plot(tuk.cld.c,col=colors, ylab="Number of Input Reads",cex.lab=1.5,cex.axis=1)
dev.off()
plot(tuk.cld.c,col=colors, ylab="Number of Input Reads",cex.lab=1.5,cex.axis=1)
# Out:
# Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: aov(formula = Input.Reads ~ Phylum, data = sub)
#
# Linear Hypotheses:
#                                    Estimate Std. Error t value Pr(>|t|)
# Chlorophyta - Bacillariophyta == 0  -282548    1074536  -0.263  1.00000
# Ciliophora - Bacillariophyta == 0   3976394    1543975   2.575  0.15432
# Cryptophyta - Bacillariophyta == 0  3439725    1633367   2.106  0.39057
# Dinophyta - Bacillariophyta == 0    1413547     870495   1.624  0.71811
# Haptophyta - Bacillariophyta == 0  -2160043    1074536  -2.010  0.45392
# Ochrophyta - Bacillariophyta == 0  -2100984    1007126  -2.086  0.40330
# ...

# %% [markdown]
# # Number of contigs

# %%
fit4 <- aov(n_seqs ~ Phylum,data=sub)
b<-TukeyHSD(fit4,"Phylum",conf.level=0.95)
tuk<-glht(fit4,linfct=mcp(Phylum="Tukey"))
summary(tuk)
tuk.cld.d<-cld(tuk)
opar<-par(mai=c(1,1,1.5,1))
options(repr.plot.width=12, repr.plot.height=10)
pdf("paper/Figure8_tukey_taxa_n_contigs.pdf",width=13,height=8.5)
par(mar=c(6,6,8,2))
plot(tuk.cld.d,col=colors, ylab="Number of Contigs",cex.lab=1.5,cex.axis=1)
dev.off()
png("paper/Figure8_tukey_taxa_n_contigs.png",width=13,height=8.5,units="in",res=1200)
plot(tuk.cld.d,col=colors, ylab="Number of Contigs",cex.lab=1.5,cex.axis=1)
dev.off()
plot(tuk.cld.d,col=colors, ylab="Number of Contigs",cex.lab=1.5,cex.axis=1)
# Out:
# Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: aov(formula = n_seqs ~ Phylum, data = sub)
#
# Linear Hypotheses:
#                                    Estimate Std. Error t value Pr(>|t|)
# Chlorophyta - Bacillariophyta == 0 -10604.3     3945.4  -2.688  0.11791
# Ciliophora - Bacillariophyta == 0   15625.9     5669.0   2.756  0.09922 .
# Cryptophyta - Bacillariophyta == 0  25057.4     5997.3   4.178  < 0.001 ***
# Dinophyta - Bacillariophyta == 0    63580.8     3213.4  19.786  < 0.001 ***
# Haptophyta - Bacillariophyta == 0    9305.3     3945.4   2.359  0.24691
# ...

# %% [markdown]
# # BUSCO

# %%
fit5 <- aov(DIB.Complete_eukaryotic_BUSCO_perc ~ Phylum,data=sub)
b<-TukeyHSD(fit5,"Phylum",conf.level=0.95)
tuk<-glht(fit5,linfct=mcp(Phylum="Tukey"))
summary(tuk)
tuk.cld.e<-cld(tuk)
opar<-par(mai=c(1,1,1.5,1))
options(repr.plot.width=12, repr.plot.height=10)
pdf("paper/Figure8_tukey_taxa_BUSCO.pdf",width=13,height=8.5)
par(mar=c(6,6,8,2))
dev.off()
plot(tuk.cld.e,col=colors, ylab="% Complete BUSCO (eukaryotic)",cex.lab=1.5,cex.axis=1)
png("paper/Figure8_tukey_taxa_BUSCO.png",width=13,height=8.5,units="in",res=1200)
par(mar=c(6,6,8,2))
plot(tuk.cld.e,col=colors, ylab="% Complete BUSCO (eukaryotic)",cex.lab=1.5,cex.axis=1)
dev.off()
plot(tuk.cld.e,col=colors, ylab="% Complete BUSCO (eukaryotic)",cex.lab=1.5,cex.axis=1)
# Out:
# Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: aov(formula = DIB.Complete_eukaryotic_BUSCO_perc ~ Phylum, data = sub)
#
# Linear Hypotheses:
#                                    Estimate Std. Error t value Pr(>|t|)
# Chlorophyta - Bacillariophyta == 0  12.4198     2.6611   4.667  < 0.001 ***
# Ciliophora - Bacillariophyta == 0    0.7864     3.8466   0.204  1.00000
# Cryptophyta - Bacillariophyta == 0   2.6262     4.0693   0.645  0.99797
# ...

# %%
fit6 <- aov(DIB.Complete_protist_BUSCO_prop ~ Phylum,data=sub)
b<-TukeyHSD(fit6,"Phylum",conf.level=0.95)
tuk<-glht(fit6,linfct=mcp(Phylum="Tukey"))
summary(tuk)
tuk.cld.f<-cld(tuk)
opar<-par(mai=c(1,1,1.5,1))
options(repr.plot.width=12, repr.plot.height=10)
pdf("paper/Figure8_tukey_taxa_BUSCO_protist.pdf",width=13,height=8.5)
par(mar=c(6,6,8,2))
plot(tuk.cld.f,col=colors, ylab="Proportion of Complete BUSCO (protist)",cex.lab=1.5,cex.axis=1)
dev.off()
png("paper/Figure8_tukey_taxa_BUSCO_protist.png",width=13,height=8.5,units="in",res=1200)
par(mar=c(6,6,8,2))
plot(tuk.cld.f,col=colors, ylab="Proportion of Complete BUSCO (protist)",cex.lab=1.5,cex.axis=1)
dev.off()
plot(tuk.cld.f,col=colors, ylab="Proportion of Complete BUSCO (protist)",cex.lab=1.5,cex.axis=1)
# Out:
# Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”Warning message in RET$pfunction("adjusted", ...):
# “Completion with error > abseps”
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: aov(formula = DIB.Complete_protist_BUSCO_prop ~ Phylum, data = sub)
#
# Linear Hypotheses:
#                                     Estimate Std. Error t value Pr(>|t|)
# Chlorophyta - Bacillariophyta == 0  0.066156   0.026500   2.496   0.1847
# Ciliophora - Bacillariophyta == 0  -0.006772   0.038306  -0.177   1.0000
# Cryptophyta - Bacillariophyta == 0 -0.035475   0.040524  -0.875   0.9867
# Dinophyta - Bacillariophyta == 0   -0.025735   0.021713  -1.185   0.9298
# Haptophyta - Bacillariophyta == 0  -0.068555   0.026659  -2.572   0.1553
# Ochrophyta - Bacillariophyta == 0  -0.039429   0.024987  -1.578   0.7469
# Others - Bacillariophyta == 0      -0.008659   0.020780  -0.417   0.9999
# ...

# %%
png("paper/Figure8_all.png", width=20, height=30,unit='in',res=1200)
#par(mfrow=c(4,1),mar=c(7,6,7,2))
#bottom, left, top and right margins
par(mfrow=c(4,1),mar=c(6,7,5,3),cex=1.5)
plot(tuk.cld.c,col=colors, ylab="Number of Input Reads",xlab="",xaxt='n',cex.lab=1.5)
plot(tuk.cld.d,col=colors, ylab="Number of Contigs",xlab="",xaxt='n',cex.lab=1.5)
plot(tuk.cld.b,col=colors, ylab="Unique k-mers",xlab="",xaxt='n',cex.lab=1.5)
plot(tuk.cld.a,col=colors,ylab="Mean %ORF",cex.lab=1.5,cex.axis=1)
dev.off()
pdf("paper/Figure8_all.pdf", width=20, height=30)
#par(mfrow=c(4,1),mar=c(7,6,7,2))
par(mfrow=c(4,1),mar=c(6,7,5,3),cex=1.5)
plot(tuk.cld.c,col=colors, ylab="Number of Input Reads",xlab="",xaxt='n',cex.lab=1.5)
plot(tuk.cld.d,col=colors, ylab="Number of Contigs",xlab="",xaxt='n',cex.lab=1.5)
plot(tuk.cld.b,col=colors, ylab="Unique k-mers",xlab="",xaxt='n',cex.lab=1.5)
plot(tuk.cld.a,col=colors,ylab="Mean %ORF",cex.lab=1.5,cex.axis=1)
dev.off()
#par(mfrow=c(4,1),mar=c(7,6,7,2))
par(mfrow=c(4,1),mar=c(6,7,5,3),cex=1.5)
plot(tuk.cld.c,col=colors, ylab="Number of Input Reads",xlab="",xaxt='n',cex.lab=1.5)
plot(tuk.cld.d,col=colors, ylab="Number of Contigs",xlab="",xaxt='n',cex.lab=1.5)
plot(tuk.cld.b,col=colors, ylab="Unique k-mers",xlab="",xaxt='n',cex.lab=1.5)
plot(tuk.cld.a,col=colors,ylab="Mean %ORF",cex.lab=1.5,cex.axis=1)
# Out:
# pdf
#   2
# pdf
#   2
# Error in plot.new(): figure margins too large
# Traceback:
#
# 1. plot(tuk.cld.c, col = colors, ylab = "Number of Input Reads",
#  .     xlab = "", xaxt = "n", cex.lab = 1.5)
# 2. plot.cld(tuk.cld.c, col = colors, ylab = "Number of Input Reads",
#  .     xlab = "", xaxt = "n", cex.lab = 1.5)
# 3. boxplot(y ~ x, data = dat, xlab = xn, ylab = yn, ...)
# 4. boxplot.formula(y ~ x, data = dat, xlab = xn, ylab = yn, ...)
# 5. boxplot(split(mf[[response]], mf[-response], drop = drop, sep = sep,
#  .     lex.order = lex.order), ...)
# 6. boxplot.default(split(mf[[response]], mf[-response], drop = drop,
#  .     sep = sep, lex.order = lex.order), ...)
# 7. do.call("bxp", c(list(z, notch = notch, width = width, varwidth = varwidth,
#  .     log = log, border = border, pars = pars, outline = outline,
#  .     horizontal = horizontal, add = add, at = at), args[namedargs]))
# 8. bxp(structure(list(stats = structure(c(8933945, 19938503, 24443795,
# ...
