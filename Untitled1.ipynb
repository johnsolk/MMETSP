# %%
list.files()
# Out:
#  [1] "all"                                 "all.dendro.png"
#  [3] "all.labels.txt"                      "all.matrix.png"
#  [5] "assembly.py"                         "basic_plots.ipynb"
#  [7] "batch1.mmetsp.OGcounts.csv"          "batch1.mmetsp.OGcounts.filtered.csv"
#  [9] "check.py"                            "clean.py"
# [11] "clustered.c3.s9.SRR_batch1.fa"       "clusterfunc.py"
# [13] "clusterfunc.pyc"                     "counts"
# [15] "dammit.py"                           "diginorm_mmetsp.py"
# [17] "Dockerfile"                          "download_mmetsp_transcriptomes.sh"
# [19] "download.txt"                        "Extract_Clusters.ipynb"
# [21] "gather_assemblies.py"                "gather-counts.py"
# [23] "getdata_tutorial.rst"                "getdata.py"
# [25] "imicrobe"                            "install-irkernel.R"
# [27] "matplotlibrc"                        "MMETSP_list"
# [29] "MMETSP_reverse_transrate_data.csv"   "MMETSP_reverse_transrate.ipynb"
# ...
